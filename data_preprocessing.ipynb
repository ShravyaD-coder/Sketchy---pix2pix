# %%
import pandas as pd
import os
import glob

# %%
root_dir = "./data_pix2pix"

image_extensions = ('*.png', '*.jpg', '*.jpeg', '*.bmp', '*.gif')

# Dictionary to hold image paths
image_paths = {}

# Walk through A and B
for folder in ['A', 'B']:
    folder_path = os.path.join(root_dir, folder)
    
    # Iterate through train, test, val
    for subset in ['train', 'test', 'val']:
        subset_path = os.path.join(folder_path, subset)
        
        # Collect image paths
        images = []
        for ext in image_extensions:
            images.extend(glob.glob(os.path.join(subset_path, ext)))
        
        # Save to dictionary
        image_paths[f"{folder}_{subset}"] = images

# Example: print paths from A_train
print(image_paths['A_train'])
# Out:
# ['./data_pix2pix/A/train/88.jpg', './data_pix2pix/A/train/76.jpg', './data_pix2pix/A/train/74.jpg', './data_pix2pix/A/train/148.jpg', './data_pix2pix/A/train/71.jpg', './data_pix2pix/A/train/72.jpg', './data_pix2pix/A/train/98.jpg', './data_pix2pix/A/train/114.jpg', './data_pix2pix/A/train/100.jpg', './data_pix2pix/A/train/128.jpg', './data_pix2pix/A/train/116.jpg', './data_pix2pix/A/train/102.jpg', './data_pix2pix/A/train/106.jpg', './data_pix2pix/A/train/112.jpg', './data_pix2pix/A/train/104.jpg', './data_pix2pix/A/train/110.jpg', './data_pix2pix/A/train/138.jpg', './data_pix2pix/A/train/108.jpg', './data_pix2pix/A/train/120.jpg', './data_pix2pix/A/train/134.jpg', './data_pix2pix/A/train/122.jpg', './data_pix2pix/A/train/136.jpg', './data_pix2pix/A/train/132.jpg', './data_pix2pix/A/train/126.jpg', './data_pix2pix/A/train/118.jpg', './data_pix2pix/A/train/130.jpg', './data_pix2pix/A/train/124.jpg', './data_pix2pix/A/train/142.jpg', './data_pix2pix/A/train/94.jpg', './data_pix2pix/A/train/80.jpg', './data_pix2pix/A/train/69.jpg', './data_pix2pix/A/train/96.jpg', './data_pix2pix/A/train/82.jpg', './data_pix2pix/A/train/140.jpg', './data_pix2pix/A/train/78.jpg', './data_pix2pix/A/train/86.jpg', './data_pix2pix/A/train/92.jpg', './data_pix2pix/A/train/144.jpg', './data_pix2pix/A/train/146.jpg', './data_pix2pix/A/train/84.jpg', './data_pix2pix/A/train/90.jpg', './data_pix2pix/A/train/109.jpeg', './data_pix2pix/A/train/125.jpeg', './data_pix2pix/A/train/133.jpeg', './data_pix2pix/A/train/113.jpeg', './data_pix2pix/A/train/105.jpeg', './data_pix2pix/A/train/129.jpeg', './data_pix2pix/A/train/89.jpeg', './data_pix2pix/A/train/70.jpeg', './data_pix2pix/A/train/145.jpeg', './data_pix2pix/A/train/85.jpeg', './data_pix2pix/A/train/93.jpeg', './data_pix2pix/A/train/149.jpeg', './data_pix2pix/A/train/115.jpeg', './data_pix2pix/A/train/103.jpeg', './data_pix2pix/A/train/77.jpeg', './data_pix2pix/A/train/139.jpeg', './data_pix2pix/A/train/119.jpeg', './data_pix2pix/A/train/123.jpeg', './data_pix2pix/A/train/135.jpeg', './data_pix2pix/A/train/83.jpeg', './data_pix2pix/A/train/95.jpeg', './data_pix2pix/A/train/99.jpeg', './data_pix2pix/A/train/143.jpeg', './data_pix2pix/A/train/75.jpeg', './data_pix2pix/A/train/101.jpeg', './data_pix2pix/A/train/117.jpeg', './data_pix2pix/A/train/137.jpeg', './data_pix2pix/A/train/79.jpeg', './data_pix2pix/A/train/121.jpeg', './data_pix2pix/A/train/97.jpeg', './data_pix2pix/A/train/81.jpeg', './data_pix2pix/A/train/141.jpeg', './data_pix2pix/A/train/131.jpeg', './data_pix2pix/A/train/127.jpeg', './data_pix2pix/A/train/73.jpeg', './data_pix2pix/A/train/107.jpeg', './data_pix2pix/A/train/150.jpeg', './data_pix2pix/A/train/111.jpeg', './data_pix2pix/A/train/147.jpeg', './data_pix2pix/A/train/91.jpeg', './data_pix2pix/A/train/68.jpeg', './data_pix2pix/A/train/87.jpeg']

# %%
import cv2
import matplotlib.pyplot as plt


"""for image in image_paths['A_train']:
    image_path = image
    image = cv2.imread(image_path)

    # Convert BGR (OpenCV) to RGB (Matplotlib)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    plt.imshow(image_rgb)
    plt.title(f"A_train image: {os.path.basename(image_path)}")
    plt.axis('off')
    plt.show()"""
# Out:
# 'for image in image_paths[\'A_train\']:\n    image_path = image\n    image = cv2.imread(image_path)\n\n    # Convert BGR (OpenCV) to RGB (Matplotlib)\n    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)\n\n    plt.imshow(image_rgb)\n    plt.title(f"A_train image: {os.path.basename(image_path)}")\n    plt.axis(\'off\')\n    plt.show()'

# %%
import cv2
import os
import glob
import shutil


# Root directory containing A and B folders
root_dir = "./data_pix2pix"
output_root_dir = "./preprocessed_images"

# Target subfolders
folders = ['A', 'B']
subfolders = ['train', 'test', 'val']

for folder in folders:
    for subset in subfolders:
        input_dir = os.path.join(root_dir, folder, subset)
        output_dir = os.path.join(output_root_dir, folder, subset)
        os.makedirs(output_dir, exist_ok=True)

        # Get all jpg and jpeg files
        jpg_paths = glob.glob(os.path.join(input_dir, '*.jpg'))
        jpeg_paths = glob.glob(os.path.join(input_dir, '*.jpeg'))

        if not jpg_paths:
            print(f"No jpg images found in {input_dir}, skipping this folder.")
            continue

        # Get target size from first jpg image
        sample_image = cv2.imread(jpg_paths[0])
        if sample_image is None:
            print(f"Failed to read {jpg_paths[0]}, skipping this folder.")
            continue

        target_size = (sample_image.shape[1], sample_image.shape[0])  # (width, height)
        print(f"Target size for {input_dir}: {target_size}")

        # Copy all jpg images to output folder
        for image_path in jpg_paths:
            filename = os.path.basename(image_path)
            save_path = os.path.join(output_dir, filename)
            shutil.copy(image_path, save_path)
            print(f"Copied jpg: {save_path}")

        # Process jpeg images
        for image_path in jpeg_paths:
            image = cv2.imread(image_path)
            if image is None:
                print(f"Failed to read {image_path}, skipping.")
                continue

            current_size = (image.shape[1], image.shape[0])  # (width, height)
            filename = os.path.basename(image_path)
            save_path = os.path.join(output_dir, filename)

            if current_size != target_size:
                # Resize if dimensions are different
                resized_image = cv2.resize(image, target_size)
                cv2.imwrite(save_path, resized_image)
                print(f"Resized and saved jpeg: {save_path}")
            else:
                # If size matches, copy as-is
                shutil.copy(image_path, save_path)
                print(f"Copied jpeg as-is: {save_path}")
# Out:
# Target size for ./data_pix2pix/A/train: (200, 250)
# Copied jpg: ./preprocessed_images/A/train/88.jpg
# Copied jpg: ./preprocessed_images/A/train/76.jpg
# Copied jpg: ./preprocessed_images/A/train/74.jpg
# Copied jpg: ./preprocessed_images/A/train/148.jpg
# Copied jpg: ./preprocessed_images/A/train/71.jpg
# Copied jpg: ./preprocessed_images/A/train/72.jpg
# Copied jpg: ./preprocessed_images/A/train/98.jpg
# Copied jpg: ./preprocessed_images/A/train/114.jpg
# Copied jpg: ./preprocessed_images/A/train/100.jpg
# Copied jpg: ./preprocessed_images/A/train/128.jpg
# Copied jpg: ./preprocessed_images/A/train/116.jpg
# Copied jpg: ./preprocessed_images/A/train/102.jpg
# Copied jpg: ./preprocessed_images/A/train/106.jpg
# Copied jpg: ./preprocessed_images/A/train/112.jpg
# Copied jpg: ./preprocessed_images/A/train/104.jpg
# Copied jpg: ./preprocessed_images/A/train/110.jpg
# Copied jpg: ./preprocessed_images/A/train/138.jpg
# Copied jpg: ./preprocessed_images/A/train/108.jpg
# Copied jpg: ./preprocessed_images/A/train/120.jpg
# Copied jpg: ./preprocessed_images/A/train/134.jpg
# Copied jpg: ./preprocessed_images/A/train/122.jpg
# Copied jpg: ./preprocessed_images/A/train/136.jpg
# Copied jpg: ./preprocessed_images/A/train/132.jpg
# Copied jpg: ./preprocessed_images/A/train/126.jpg
# Copied jpg: ./preprocessed_images/A/train/118.jpg
# Copied jpg: ./preprocessed_images/A/train/130.jpg
# Copied jpg: ./preprocessed_images/A/train/124.jpg
# Copied jpg: ./preprocessed_images/A/train/142.jpg
# Copied jpg: ./preprocessed_images/A/train/94.jpg
# Copied jpg: ./preprocessed_images/A/train/80.jpg
# Copied jpg: ./preprocessed_images/A/train/69.jpg
# Copied jpg: ./preprocessed_images/A/train/96.jpg
# Copied jpg: ./preprocessed_images/A/train/82.jpg
# Copied jpg: ./preprocessed_images/A/train/140.jpg
# Copied jpg: ./preprocessed_images/A/train/78.jpg
# Copied jpg: ./preprocessed_images/A/train/86.jpg
# Copied jpg: ./preprocessed_images/A/train/92.jpg
# Copied jpg: ./preprocessed_images/A/train/144.jpg
# Copied jpg: ./preprocessed_images/A/train/146.jpg
# Copied jpg: ./preprocessed_images/A/train/84.jpg
# Copied jpg: ./preprocessed_images/A/train/90.jpg
# Resized and saved jpeg: ./preprocessed_images/A/train/109.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/125.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/133.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/113.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/105.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/129.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/89.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/70.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/145.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/85.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/93.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/149.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/115.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/103.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/77.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/139.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/119.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/123.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/135.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/83.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/95.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/99.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/143.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/75.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/101.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/117.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/137.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/79.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/121.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/97.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/81.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/141.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/131.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/127.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/73.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/107.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/150.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/111.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/147.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/91.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/68.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/train/87.jpeg
# Target size for ./data_pix2pix/A/test: (200, 250)
# Copied jpg: ./preprocessed_images/A/test/49.jpg
# Copied jpg: ./preprocessed_images/A/test/9.jpg
# Copied jpg: ./preprocessed_images/A/test/29.jpg
# Copied jpg: ./preprocessed_images/A/test/15.jpg
# Copied jpg: ./preprocessed_images/A/test/17.jpg
# Copied jpg: ./preprocessed_images/A/test/13.jpg
# Copied jpg: ./preprocessed_images/A/test/39.jpg
# Copied jpg: ./preprocessed_images/A/test/11.jpg
# Copied jpg: ./preprocessed_images/A/test/21.jpg
# Copied jpg: ./preprocessed_images/A/test/35.jpg
# Copied jpg: ./preprocessed_images/A/test/23.jpg
# Copied jpg: ./preprocessed_images/A/test/37.jpg
# Copied jpg: ./preprocessed_images/A/test/33.jpg
# Copied jpg: ./preprocessed_images/A/test/27.jpg
# Copied jpg: ./preprocessed_images/A/test/31.jpg
# Copied jpg: ./preprocessed_images/A/test/25.jpg
# Copied jpg: ./preprocessed_images/A/test/19.jpg
# Copied jpg: ./preprocessed_images/A/test/5.jpg
# Copied jpg: ./preprocessed_images/A/test/43.jpg
# Copied jpg: ./preprocessed_images/A/test/7.jpg
# Copied jpg: ./preprocessed_images/A/test/41.jpg
# Copied jpg: ./preprocessed_images/A/test/45.jpg
# Copied jpg: ./preprocessed_images/A/test/3.jpg
# Copied jpg: ./preprocessed_images/A/test/47.jpg
# Copied jpg: ./preprocessed_images/A/test/1.jpg
# Resized and saved jpeg: ./preprocessed_images/A/test/10.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/26.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/30.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/50.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/46.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/20.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/36.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/16.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/6.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/40.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/34.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/8.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/22.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/18.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/38.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/4.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/14.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/42.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/2.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/28.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/12.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/32.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/24.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/48.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/test/44.jpeg
# Target size for ./data_pix2pix/A/val: (200, 250)
# Copied jpg: ./preprocessed_images/A/val/63.jpg
# Copied jpg: ./preprocessed_images/A/val/61.jpg
# Copied jpg: ./preprocessed_images/A/val/59.jpg
# Copied jpg: ./preprocessed_images/A/val/65.jpg
# Copied jpg: ./preprocessed_images/A/val/67.jpg
# Copied jpg: ./preprocessed_images/A/val/57.jpg
# Copied jpg: ./preprocessed_images/A/val/55.jpg
# Copied jpg: ./preprocessed_images/A/val/51.jpg
# Copied jpg: ./preprocessed_images/A/val/53.jpg
# Resized and saved jpeg: ./preprocessed_images/A/val/66.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/val/56.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/val/60.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/val/54.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/val/58.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/val/62.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/val/64.jpeg
# Resized and saved jpeg: ./preprocessed_images/A/val/52.jpeg
# Target size for ./data_pix2pix/B/train: (767, 816)
# Copied jpg: ./preprocessed_images/B/train/77.jpg
# Copied jpg: ./preprocessed_images/B/train/88.jpg
# Copied jpg: ./preprocessed_images/B/train/89.jpg
# Copied jpg: ./preprocessed_images/B/train/76.jpg
# Copied jpg: ./preprocessed_images/B/train/74.jpg
# Copied jpg: ./preprocessed_images/B/train/149.jpg
# Copied jpg: ./preprocessed_images/B/train/148.jpg
# Copied jpg: ./preprocessed_images/B/train/75.jpg
# Copied jpg: ./preprocessed_images/B/train/71.jpg
# Copied jpg: ./preprocessed_images/B/train/70.jpg
# Copied jpg: ./preprocessed_images/B/train/72.jpg
# Copied jpg: ./preprocessed_images/B/train/99.jpg
# Copied jpg: ./preprocessed_images/B/train/98.jpg
# Copied jpg: ./preprocessed_images/B/train/73.jpg
# Copied jpg: ./preprocessed_images/B/train/129.jpg
# Copied jpg: ./preprocessed_images/B/train/101.jpg
# Copied jpg: ./preprocessed_images/B/train/115.jpg
# Copied jpg: ./preprocessed_images/B/train/114.jpg
# Copied jpg: ./preprocessed_images/B/train/100.jpg
# Copied jpg: ./preprocessed_images/B/train/128.jpg
# Copied jpg: ./preprocessed_images/B/train/116.jpg
# Copied jpg: ./preprocessed_images/B/train/102.jpg
# Copied jpg: ./preprocessed_images/B/train/103.jpg
# Copied jpg: ./preprocessed_images/B/train/117.jpg
# Copied jpg: ./preprocessed_images/B/train/113.jpg
# Copied jpg: ./preprocessed_images/B/train/107.jpg
# Copied jpg: ./preprocessed_images/B/train/106.jpg
# Copied jpg: ./preprocessed_images/B/train/112.jpg
# Copied jpg: ./preprocessed_images/B/train/104.jpg
# Copied jpg: ./preprocessed_images/B/train/110.jpg
# Copied jpg: ./preprocessed_images/B/train/138.jpg
# Copied jpg: ./preprocessed_images/B/train/139.jpg
# Copied jpg: ./preprocessed_images/B/train/111.jpg
# Copied jpg: ./preprocessed_images/B/train/105.jpg
# Copied jpg: ./preprocessed_images/B/train/108.jpg
# Copied jpg: ./preprocessed_images/B/train/120.jpg
# Copied jpg: ./preprocessed_images/B/train/134.jpg
# Copied jpg: ./preprocessed_images/B/train/135.jpg
# Copied jpg: ./preprocessed_images/B/train/121.jpg
# Copied jpg: ./preprocessed_images/B/train/109.jpg
# Copied jpg: ./preprocessed_images/B/train/137.jpg
# Copied jpg: ./preprocessed_images/B/train/123.jpg
# Copied jpg: ./preprocessed_images/B/train/122.jpg
# Copied jpg: ./preprocessed_images/B/train/136.jpg
# Copied jpg: ./preprocessed_images/B/train/132.jpg
# Copied jpg: ./preprocessed_images/B/train/126.jpg
# Copied jpg: ./preprocessed_images/B/train/127.jpg
# Copied jpg: ./preprocessed_images/B/train/133.jpg
# Copied jpg: ./preprocessed_images/B/train/125.jpg
# Copied jpg: ./preprocessed_images/B/train/131.jpg
# Copied jpg: ./preprocessed_images/B/train/119.jpg
# Copied jpg: ./preprocessed_images/B/train/118.jpg
# Copied jpg: ./preprocessed_images/B/train/130.jpg
# Copied jpg: ./preprocessed_images/B/train/124.jpg
# Copied jpg: ./preprocessed_images/B/train/81.jpg
# Copied jpg: ./preprocessed_images/B/train/95.jpg
# Copied jpg: ./preprocessed_images/B/train/143.jpg
# Copied jpg: ./preprocessed_images/B/train/142.jpg
# Copied jpg: ./preprocessed_images/B/train/94.jpg
# Copied jpg: ./preprocessed_images/B/train/80.jpg
# Copied jpg: ./preprocessed_images/B/train/69.jpg
# Copied jpg: ./preprocessed_images/B/train/96.jpg
# Copied jpg: ./preprocessed_images/B/train/82.jpg
# Copied jpg: ./preprocessed_images/B/train/140.jpg
# Copied jpg: ./preprocessed_images/B/train/141.jpg
# Copied jpg: ./preprocessed_images/B/train/83.jpg
# Copied jpg: ./preprocessed_images/B/train/97.jpg
# Copied jpg: ./preprocessed_images/B/train/68.jpg
# Copied jpg: ./preprocessed_images/B/train/78.jpg
# Copied jpg: ./preprocessed_images/B/train/145.jpg
# Copied jpg: ./preprocessed_images/B/train/93.jpg
# Copied jpg: ./preprocessed_images/B/train/87.jpg
# Copied jpg: ./preprocessed_images/B/train/86.jpg
# Copied jpg: ./preprocessed_images/B/train/92.jpg
# Copied jpg: ./preprocessed_images/B/train/144.jpg
# Copied jpg: ./preprocessed_images/B/train/150.jpg
# Copied jpg: ./preprocessed_images/B/train/79.jpg
# Copied jpg: ./preprocessed_images/B/train/146.jpg
# Copied jpg: ./preprocessed_images/B/train/84.jpg
# Copied jpg: ./preprocessed_images/B/train/90.jpg
# Copied jpg: ./preprocessed_images/B/train/91.jpg
# Copied jpg: ./preprocessed_images/B/train/85.jpg
# Copied jpg: ./preprocessed_images/B/train/147.jpg
# Target size for ./data_pix2pix/B/test: (767, 816)
# Copied jpg: ./preprocessed_images/B/test/48.jpg
# Copied jpg: ./preprocessed_images/B/test/49.jpg
# Copied jpg: ./preprocessed_images/B/test/8.jpg
# Copied jpg: ./preprocessed_images/B/test/9.jpg
# Copied jpg: ./preprocessed_images/B/test/14.jpg
# Copied jpg: ./preprocessed_images/B/test/28.jpg
# Copied jpg: ./preprocessed_images/B/test/29.jpg
# Copied jpg: ./preprocessed_images/B/test/15.jpg
# Copied jpg: ./preprocessed_images/B/test/17.jpg
# Copied jpg: ./preprocessed_images/B/test/16.jpg
# Copied jpg: ./preprocessed_images/B/test/12.jpg
# Copied jpg: ./preprocessed_images/B/test/13.jpg
# Copied jpg: ./preprocessed_images/B/test/39.jpg
# Copied jpg: ./preprocessed_images/B/test/11.jpg
# Copied jpg: ./preprocessed_images/B/test/10.jpg
# Copied jpg: ./preprocessed_images/B/test/38.jpg
# Copied jpg: ./preprocessed_images/B/test/21.jpg
# Copied jpg: ./preprocessed_images/B/test/35.jpg
# Copied jpg: ./preprocessed_images/B/test/34.jpg
# Copied jpg: ./preprocessed_images/B/test/20.jpg
# Copied jpg: ./preprocessed_images/B/test/36.jpg
# Copied jpg: ./preprocessed_images/B/test/22.jpg
# Copied jpg: ./preprocessed_images/B/test/23.jpg
# Copied jpg: ./preprocessed_images/B/test/37.jpg
# Copied jpg: ./preprocessed_images/B/test/33.jpg
# Copied jpg: ./preprocessed_images/B/test/27.jpg
# Copied jpg: ./preprocessed_images/B/test/26.jpg
# Copied jpg: ./preprocessed_images/B/test/32.jpg
# Copied jpg: ./preprocessed_images/B/test/18.jpg
# Copied jpg: ./preprocessed_images/B/test/24.jpg
# Copied jpg: ./preprocessed_images/B/test/30.jpg
# Copied jpg: ./preprocessed_images/B/test/31.jpg
# Copied jpg: ./preprocessed_images/B/test/25.jpg
# Copied jpg: ./preprocessed_images/B/test/19.jpg
# Copied jpg: ./preprocessed_images/B/test/42.jpg
# Copied jpg: ./preprocessed_images/B/test/4.jpg
# Copied jpg: ./preprocessed_images/B/test/5.jpg
# Copied jpg: ./preprocessed_images/B/test/43.jpg
# Copied jpg: ./preprocessed_images/B/test/7.jpg
# Copied jpg: ./preprocessed_images/B/test/41.jpg
# Copied jpg: ./preprocessed_images/B/test/40.jpg
# Copied jpg: ./preprocessed_images/B/test/6.jpg
# Copied jpg: ./preprocessed_images/B/test/2.jpg
# Copied jpg: ./preprocessed_images/B/test/50.jpg
# Copied jpg: ./preprocessed_images/B/test/44.jpg
# Copied jpg: ./preprocessed_images/B/test/45.jpg
# Copied jpg: ./preprocessed_images/B/test/3.jpg
# Copied jpg: ./preprocessed_images/B/test/47.jpg
# Copied jpg: ./preprocessed_images/B/test/1.jpg
# Copied jpg: ./preprocessed_images/B/test/46.jpg
# Target size for ./data_pix2pix/B/val: (200, 250)
# Copied jpg: ./preprocessed_images/B/val/63.jpg
# Copied jpg: ./preprocessed_images/B/val/62.jpg
# Copied jpg: ./preprocessed_images/B/val/60.jpg
# Copied jpg: ./preprocessed_images/B/val/61.jpg
# Copied jpg: ./preprocessed_images/B/val/59.jpg
# Copied jpg: ./preprocessed_images/B/val/65.jpg
# Copied jpg: ./preprocessed_images/B/val/64.jpg
# Copied jpg: ./preprocessed_images/B/val/58.jpg
# Copied jpg: ./preprocessed_images/B/val/66.jpg
# Copied jpg: ./preprocessed_images/B/val/67.jpg
# Copied jpg: ./preprocessed_images/B/val/56.jpg
# Copied jpg: ./preprocessed_images/B/val/57.jpg
# Copied jpg: ./preprocessed_images/B/val/55.jpg
# Copied jpg: ./preprocessed_images/B/val/54.jpg
# Copied jpg: ./preprocessed_images/B/val/51.jpg
# Copied jpg: ./preprocessed_images/B/val/53.jpg
# Copied jpg: ./preprocessed_images/B/val/52.jpg

# %%
import cv2
import os
import glob

# Root directory containing A and B folders
root_dir = "./preprocessed_images"
output_root_dir = './preprocessed_folder_final'

# Target subfolders and folders
folders = ['A', 'B']
subfolders = ['train', 'test', 'val']

# Desired target size (width, height)
target_size = (200, 250)

# Supported extensions
image_extensions = ['*.jpg', '*.jpeg']

for folder in folders:
    for subset in subfolders:
        input_dir = os.path.join(root_dir, folder, subset)
        output_dir = os.path.join(output_root_dir, folder, subset)
        os.makedirs(output_dir, exist_ok=True)

        # Get all jpg and jpeg files
        image_paths = []
        for ext in image_extensions:
            image_paths.extend(glob.glob(os.path.join(input_dir, ext)))

        if not image_paths:
            print(f"No images found in {input_dir}. Skipping.")
            continue

        print(f"Processing {len(image_paths)} images in {input_dir}")

        for image_path in image_paths:
            image = cv2.imread(image_path)
            if image is None:
                print(f"Failed to read {image_path}, skipping.")
                continue

            # Convert to grayscale
            gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            # Apply CLAHE (adaptive histogram equalization)
            clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
            equalized_image = clahe.apply(gray_image)

            # Convert back to 3-channel grayscale
            gray_3ch_image = cv2.cvtColor(equalized_image, cv2.COLOR_GRAY2BGR)


            # Resize
            resized_image = cv2.resize(gray_3ch_image, target_size)

            # Save with same base filename but .jpg extension
            base_filename = os.path.splitext(os.path.basename(image_path))[0]
            save_path = os.path.join(output_dir, base_filename + '.jpg')

            cv2.imwrite(save_path, resized_image)
            print(f"Saved: {save_path}")

print(" All images processed, resized, and saved as .jpg.")
# Out:
# Processing 83 images in ./preprocessed_images/A/train
# Saved: ./preprocessed_folder_final/A/train/88.jpg
# Saved: ./preprocessed_folder_final/A/train/76.jpg
# Saved: ./preprocessed_folder_final/A/train/74.jpg
# Saved: ./preprocessed_folder_final/A/train/148.jpg
# Saved: ./preprocessed_folder_final/A/train/71.jpg
# Saved: ./preprocessed_folder_final/A/train/72.jpg
# Saved: ./preprocessed_folder_final/A/train/98.jpg
# Saved: ./preprocessed_folder_final/A/train/114.jpg
# Saved: ./preprocessed_folder_final/A/train/100.jpg
# Saved: ./preprocessed_folder_final/A/train/128.jpg
# Saved: ./preprocessed_folder_final/A/train/116.jpg
# Saved: ./preprocessed_folder_final/A/train/102.jpg
# Saved: ./preprocessed_folder_final/A/train/106.jpg
# Saved: ./preprocessed_folder_final/A/train/112.jpg
# Saved: ./preprocessed_folder_final/A/train/104.jpg
# Saved: ./preprocessed_folder_final/A/train/110.jpg
# Saved: ./preprocessed_folder_final/A/train/138.jpg
# Saved: ./preprocessed_folder_final/A/train/108.jpg
# Saved: ./preprocessed_folder_final/A/train/120.jpg
# Saved: ./preprocessed_folder_final/A/train/134.jpg
# Saved: ./preprocessed_folder_final/A/train/122.jpg
# Saved: ./preprocessed_folder_final/A/train/136.jpg
# Saved: ./preprocessed_folder_final/A/train/132.jpg
# Saved: ./preprocessed_folder_final/A/train/126.jpg
# Saved: ./preprocessed_folder_final/A/train/118.jpg
# Saved: ./preprocessed_folder_final/A/train/130.jpg
# Saved: ./preprocessed_folder_final/A/train/124.jpg
# Saved: ./preprocessed_folder_final/A/train/142.jpg
# Saved: ./preprocessed_folder_final/A/train/94.jpg
# Saved: ./preprocessed_folder_final/A/train/80.jpg
# Saved: ./preprocessed_folder_final/A/train/69.jpg
# Saved: ./preprocessed_folder_final/A/train/96.jpg
# Saved: ./preprocessed_folder_final/A/train/82.jpg
# Saved: ./preprocessed_folder_final/A/train/140.jpg
# Saved: ./preprocessed_folder_final/A/train/78.jpg
# Saved: ./preprocessed_folder_final/A/train/86.jpg
# Saved: ./preprocessed_folder_final/A/train/92.jpg
# Saved: ./preprocessed_folder_final/A/train/144.jpg
# Saved: ./preprocessed_folder_final/A/train/146.jpg
# Saved: ./preprocessed_folder_final/A/train/84.jpg
# Saved: ./preprocessed_folder_final/A/train/90.jpg
# Saved: ./preprocessed_folder_final/A/train/109.jpg
# Saved: ./preprocessed_folder_final/A/train/125.jpg
# Saved: ./preprocessed_folder_final/A/train/133.jpg
# Saved: ./preprocessed_folder_final/A/train/113.jpg
# Saved: ./preprocessed_folder_final/A/train/105.jpg
# Saved: ./preprocessed_folder_final/A/train/129.jpg
# Saved: ./preprocessed_folder_final/A/train/89.jpg
# Saved: ./preprocessed_folder_final/A/train/70.jpg
# Saved: ./preprocessed_folder_final/A/train/145.jpg
# Saved: ./preprocessed_folder_final/A/train/85.jpg
# Saved: ./preprocessed_folder_final/A/train/93.jpg
# Saved: ./preprocessed_folder_final/A/train/149.jpg
# Saved: ./preprocessed_folder_final/A/train/115.jpg
# Saved: ./preprocessed_folder_final/A/train/103.jpg
# Saved: ./preprocessed_folder_final/A/train/77.jpg
# Saved: ./preprocessed_folder_final/A/train/139.jpg
# Saved: ./preprocessed_folder_final/A/train/119.jpg
# Saved: ./preprocessed_folder_final/A/train/123.jpg
# Saved: ./preprocessed_folder_final/A/train/135.jpg
# Saved: ./preprocessed_folder_final/A/train/83.jpg
# Saved: ./preprocessed_folder_final/A/train/95.jpg
# Saved: ./preprocessed_folder_final/A/train/99.jpg
# Saved: ./preprocessed_folder_final/A/train/143.jpg
# Saved: ./preprocessed_folder_final/A/train/75.jpg
# Saved: ./preprocessed_folder_final/A/train/101.jpg
# Saved: ./preprocessed_folder_final/A/train/117.jpg
# Saved: ./preprocessed_folder_final/A/train/137.jpg
# Saved: ./preprocessed_folder_final/A/train/79.jpg
# Saved: ./preprocessed_folder_final/A/train/121.jpg
# Saved: ./preprocessed_folder_final/A/train/97.jpg
# Saved: ./preprocessed_folder_final/A/train/81.jpg
# Saved: ./preprocessed_folder_final/A/train/141.jpg
# Saved: ./preprocessed_folder_final/A/train/131.jpg
# Saved: ./preprocessed_folder_final/A/train/127.jpg
# Saved: ./preprocessed_folder_final/A/train/73.jpg
# Saved: ./preprocessed_folder_final/A/train/107.jpg
# Saved: ./preprocessed_folder_final/A/train/150.jpg
# Saved: ./preprocessed_folder_final/A/train/111.jpg
# Saved: ./preprocessed_folder_final/A/train/147.jpg
# Saved: ./preprocessed_folder_final/A/train/91.jpg
# Saved: ./preprocessed_folder_final/A/train/68.jpg
# Saved: ./preprocessed_folder_final/A/train/87.jpg
# Processing 50 images in ./preprocessed_images/A/test
# Saved: ./preprocessed_folder_final/A/test/49.jpg
# Saved: ./preprocessed_folder_final/A/test/9.jpg
# Saved: ./preprocessed_folder_final/A/test/29.jpg
# Saved: ./preprocessed_folder_final/A/test/15.jpg
# Saved: ./preprocessed_folder_final/A/test/17.jpg
# Saved: ./preprocessed_folder_final/A/test/13.jpg
# Saved: ./preprocessed_folder_final/A/test/39.jpg
# Saved: ./preprocessed_folder_final/A/test/11.jpg
# Saved: ./preprocessed_folder_final/A/test/21.jpg
# Saved: ./preprocessed_folder_final/A/test/35.jpg
# Saved: ./preprocessed_folder_final/A/test/23.jpg
# Saved: ./preprocessed_folder_final/A/test/37.jpg
# Saved: ./preprocessed_folder_final/A/test/33.jpg
# Saved: ./preprocessed_folder_final/A/test/27.jpg
# Saved: ./preprocessed_folder_final/A/test/31.jpg
# Saved: ./preprocessed_folder_final/A/test/25.jpg
# Saved: ./preprocessed_folder_final/A/test/19.jpg
# Saved: ./preprocessed_folder_final/A/test/5.jpg
# Saved: ./preprocessed_folder_final/A/test/43.jpg
# Saved: ./preprocessed_folder_final/A/test/7.jpg
# Saved: ./preprocessed_folder_final/A/test/41.jpg
# Saved: ./preprocessed_folder_final/A/test/45.jpg
# Saved: ./preprocessed_folder_final/A/test/3.jpg
# Saved: ./preprocessed_folder_final/A/test/47.jpg
# Saved: ./preprocessed_folder_final/A/test/1.jpg
# Saved: ./preprocessed_folder_final/A/test/10.jpg
# Saved: ./preprocessed_folder_final/A/test/26.jpg
# Saved: ./preprocessed_folder_final/A/test/30.jpg
# Saved: ./preprocessed_folder_final/A/test/50.jpg
# Saved: ./preprocessed_folder_final/A/test/46.jpg
# Saved: ./preprocessed_folder_final/A/test/20.jpg
# Saved: ./preprocessed_folder_final/A/test/36.jpg
# Saved: ./preprocessed_folder_final/A/test/16.jpg
# Saved: ./preprocessed_folder_final/A/test/6.jpg
# Saved: ./preprocessed_folder_final/A/test/40.jpg
# Saved: ./preprocessed_folder_final/A/test/34.jpg
# Saved: ./preprocessed_folder_final/A/test/8.jpg
# Saved: ./preprocessed_folder_final/A/test/22.jpg
# Saved: ./preprocessed_folder_final/A/test/18.jpg
# Saved: ./preprocessed_folder_final/A/test/38.jpg
# Saved: ./preprocessed_folder_final/A/test/4.jpg
# Saved: ./preprocessed_folder_final/A/test/14.jpg
# Saved: ./preprocessed_folder_final/A/test/42.jpg
# Saved: ./preprocessed_folder_final/A/test/2.jpg
# Saved: ./preprocessed_folder_final/A/test/28.jpg
# Saved: ./preprocessed_folder_final/A/test/12.jpg
# Saved: ./preprocessed_folder_final/A/test/32.jpg
# Saved: ./preprocessed_folder_final/A/test/24.jpg
# Saved: ./preprocessed_folder_final/A/test/48.jpg
# Saved: ./preprocessed_folder_final/A/test/44.jpg
# Processing 17 images in ./preprocessed_images/A/val
# Saved: ./preprocessed_folder_final/A/val/63.jpg
# Saved: ./preprocessed_folder_final/A/val/61.jpg
# Saved: ./preprocessed_folder_final/A/val/59.jpg
# Saved: ./preprocessed_folder_final/A/val/65.jpg
# Saved: ./preprocessed_folder_final/A/val/67.jpg
# Saved: ./preprocessed_folder_final/A/val/57.jpg
# Saved: ./preprocessed_folder_final/A/val/55.jpg
# Saved: ./preprocessed_folder_final/A/val/51.jpg
# Saved: ./preprocessed_folder_final/A/val/53.jpg
# Saved: ./preprocessed_folder_final/A/val/66.jpg
# Saved: ./preprocessed_folder_final/A/val/56.jpg
# Saved: ./preprocessed_folder_final/A/val/60.jpg
# Saved: ./preprocessed_folder_final/A/val/54.jpg
# Saved: ./preprocessed_folder_final/A/val/58.jpg
# Saved: ./preprocessed_folder_final/A/val/62.jpg
# Saved: ./preprocessed_folder_final/A/val/64.jpg
# Saved: ./preprocessed_folder_final/A/val/52.jpg
# Processing 83 images in ./preprocessed_images/B/train
# Saved: ./preprocessed_folder_final/B/train/77.jpg
# Saved: ./preprocessed_folder_final/B/train/88.jpg
# Saved: ./preprocessed_folder_final/B/train/89.jpg
# Saved: ./preprocessed_folder_final/B/train/76.jpg
# Saved: ./preprocessed_folder_final/B/train/74.jpg
# Saved: ./preprocessed_folder_final/B/train/149.jpg
# Saved: ./preprocessed_folder_final/B/train/148.jpg
# Saved: ./preprocessed_folder_final/B/train/75.jpg
# Saved: ./preprocessed_folder_final/B/train/71.jpg
# Saved: ./preprocessed_folder_final/B/train/70.jpg
# Saved: ./preprocessed_folder_final/B/train/72.jpg
# Saved: ./preprocessed_folder_final/B/train/99.jpg
# Saved: ./preprocessed_folder_final/B/train/98.jpg
# Saved: ./preprocessed_folder_final/B/train/73.jpg
# Saved: ./preprocessed_folder_final/B/train/129.jpg
# Saved: ./preprocessed_folder_final/B/train/101.jpg
# Saved: ./preprocessed_folder_final/B/train/115.jpg
# Saved: ./preprocessed_folder_final/B/train/114.jpg
# Saved: ./preprocessed_folder_final/B/train/100.jpg
# Saved: ./preprocessed_folder_final/B/train/128.jpg
# Saved: ./preprocessed_folder_final/B/train/116.jpg
# Saved: ./preprocessed_folder_final/B/train/102.jpg
# Saved: ./preprocessed_folder_final/B/train/103.jpg
# Saved: ./preprocessed_folder_final/B/train/117.jpg
# Saved: ./preprocessed_folder_final/B/train/113.jpg
# Saved: ./preprocessed_folder_final/B/train/107.jpg
# Saved: ./preprocessed_folder_final/B/train/106.jpg
# Saved: ./preprocessed_folder_final/B/train/112.jpg
# Saved: ./preprocessed_folder_final/B/train/104.jpg
# Saved: ./preprocessed_folder_final/B/train/110.jpg
# Saved: ./preprocessed_folder_final/B/train/138.jpg
# Saved: ./preprocessed_folder_final/B/train/139.jpg
# Saved: ./preprocessed_folder_final/B/train/111.jpg
# Saved: ./preprocessed_folder_final/B/train/105.jpg
# Saved: ./preprocessed_folder_final/B/train/108.jpg
# Saved: ./preprocessed_folder_final/B/train/120.jpg
# Saved: ./preprocessed_folder_final/B/train/134.jpg
# Saved: ./preprocessed_folder_final/B/train/135.jpg
# Saved: ./preprocessed_folder_final/B/train/121.jpg
# Saved: ./preprocessed_folder_final/B/train/109.jpg
# Saved: ./preprocessed_folder_final/B/train/137.jpg
# Saved: ./preprocessed_folder_final/B/train/123.jpg
# Saved: ./preprocessed_folder_final/B/train/122.jpg
# Saved: ./preprocessed_folder_final/B/train/136.jpg
# Saved: ./preprocessed_folder_final/B/train/132.jpg
# Saved: ./preprocessed_folder_final/B/train/126.jpg
# Saved: ./preprocessed_folder_final/B/train/127.jpg
# Saved: ./preprocessed_folder_final/B/train/133.jpg
# Saved: ./preprocessed_folder_final/B/train/125.jpg
# Saved: ./preprocessed_folder_final/B/train/131.jpg
# Saved: ./preprocessed_folder_final/B/train/119.jpg
# Saved: ./preprocessed_folder_final/B/train/118.jpg
# Saved: ./preprocessed_folder_final/B/train/130.jpg
# Saved: ./preprocessed_folder_final/B/train/124.jpg
# Saved: ./preprocessed_folder_final/B/train/81.jpg
# Saved: ./preprocessed_folder_final/B/train/95.jpg
# Saved: ./preprocessed_folder_final/B/train/143.jpg
# Saved: ./preprocessed_folder_final/B/train/142.jpg
# Saved: ./preprocessed_folder_final/B/train/94.jpg
# Saved: ./preprocessed_folder_final/B/train/80.jpg
# Saved: ./preprocessed_folder_final/B/train/69.jpg
# Saved: ./preprocessed_folder_final/B/train/96.jpg
# Saved: ./preprocessed_folder_final/B/train/82.jpg
# Saved: ./preprocessed_folder_final/B/train/140.jpg
# Saved: ./preprocessed_folder_final/B/train/141.jpg
# Saved: ./preprocessed_folder_final/B/train/83.jpg
# Saved: ./preprocessed_folder_final/B/train/97.jpg
# Saved: ./preprocessed_folder_final/B/train/68.jpg
# Saved: ./preprocessed_folder_final/B/train/78.jpg
# Saved: ./preprocessed_folder_final/B/train/145.jpg
# Saved: ./preprocessed_folder_final/B/train/93.jpg
# Saved: ./preprocessed_folder_final/B/train/87.jpg
# Saved: ./preprocessed_folder_final/B/train/86.jpg
# Saved: ./preprocessed_folder_final/B/train/92.jpg
# Saved: ./preprocessed_folder_final/B/train/144.jpg
# Saved: ./preprocessed_folder_final/B/train/150.jpg
# Saved: ./preprocessed_folder_final/B/train/79.jpg
# Saved: ./preprocessed_folder_final/B/train/146.jpg
# Saved: ./preprocessed_folder_final/B/train/84.jpg
# Saved: ./preprocessed_folder_final/B/train/90.jpg
# Saved: ./preprocessed_folder_final/B/train/91.jpg
# Saved: ./preprocessed_folder_final/B/train/85.jpg
# Saved: ./preprocessed_folder_final/B/train/147.jpg
# Processing 50 images in ./preprocessed_images/B/test
# Saved: ./preprocessed_folder_final/B/test/48.jpg
# Saved: ./preprocessed_folder_final/B/test/49.jpg
# Saved: ./preprocessed_folder_final/B/test/8.jpg
# Saved: ./preprocessed_folder_final/B/test/9.jpg
# Saved: ./preprocessed_folder_final/B/test/14.jpg
# Saved: ./preprocessed_folder_final/B/test/28.jpg
# Saved: ./preprocessed_folder_final/B/test/29.jpg
# Saved: ./preprocessed_folder_final/B/test/15.jpg
# Saved: ./preprocessed_folder_final/B/test/17.jpg
# Saved: ./preprocessed_folder_final/B/test/16.jpg
# Saved: ./preprocessed_folder_final/B/test/12.jpg
# Saved: ./preprocessed_folder_final/B/test/13.jpg
# Saved: ./preprocessed_folder_final/B/test/39.jpg
# Saved: ./preprocessed_folder_final/B/test/11.jpg
# Saved: ./preprocessed_folder_final/B/test/10.jpg
# Saved: ./preprocessed_folder_final/B/test/38.jpg
# Saved: ./preprocessed_folder_final/B/test/21.jpg
# Saved: ./preprocessed_folder_final/B/test/35.jpg
# Saved: ./preprocessed_folder_final/B/test/34.jpg
# Saved: ./preprocessed_folder_final/B/test/20.jpg
# Saved: ./preprocessed_folder_final/B/test/36.jpg
# Saved: ./preprocessed_folder_final/B/test/22.jpg
# Saved: ./preprocessed_folder_final/B/test/23.jpg
# Saved: ./preprocessed_folder_final/B/test/37.jpg
# Saved: ./preprocessed_folder_final/B/test/33.jpg
# Saved: ./preprocessed_folder_final/B/test/27.jpg
# Saved: ./preprocessed_folder_final/B/test/26.jpg
# Saved: ./preprocessed_folder_final/B/test/32.jpg
# Saved: ./preprocessed_folder_final/B/test/18.jpg
# Saved: ./preprocessed_folder_final/B/test/24.jpg
# Saved: ./preprocessed_folder_final/B/test/30.jpg
# Saved: ./preprocessed_folder_final/B/test/31.jpg
# Saved: ./preprocessed_folder_final/B/test/25.jpg
# Saved: ./preprocessed_folder_final/B/test/19.jpg
# Saved: ./preprocessed_folder_final/B/test/42.jpg
# Saved: ./preprocessed_folder_final/B/test/4.jpg
# Saved: ./preprocessed_folder_final/B/test/5.jpg
# Saved: ./preprocessed_folder_final/B/test/43.jpg
# Saved: ./preprocessed_folder_final/B/test/7.jpg
# Saved: ./preprocessed_folder_final/B/test/41.jpg
# Saved: ./preprocessed_folder_final/B/test/40.jpg
# Saved: ./preprocessed_folder_final/B/test/6.jpg
# Saved: ./preprocessed_folder_final/B/test/2.jpg
# Saved: ./preprocessed_folder_final/B/test/50.jpg
# Saved: ./preprocessed_folder_final/B/test/44.jpg
# Saved: ./preprocessed_folder_final/B/test/45.jpg
# Saved: ./preprocessed_folder_final/B/test/3.jpg
# Saved: ./preprocessed_folder_final/B/test/47.jpg
# Saved: ./preprocessed_folder_final/B/test/1.jpg
# Saved: ./preprocessed_folder_final/B/test/46.jpg
# Processing 17 images in ./preprocessed_images/B/val
# Saved: ./preprocessed_folder_final/B/val/63.jpg
# Saved: ./preprocessed_folder_final/B/val/62.jpg
# Saved: ./preprocessed_folder_final/B/val/60.jpg
# Saved: ./preprocessed_folder_final/B/val/61.jpg
# Saved: ./preprocessed_folder_final/B/val/59.jpg
# Saved: ./preprocessed_folder_final/B/val/65.jpg
# Saved: ./preprocessed_folder_final/B/val/64.jpg
# Saved: ./preprocessed_folder_final/B/val/58.jpg
# Saved: ./preprocessed_folder_final/B/val/66.jpg
# Saved: ./preprocessed_folder_final/B/val/67.jpg
# Saved: ./preprocessed_folder_final/B/val/56.jpg
# Saved: ./preprocessed_folder_final/B/val/57.jpg
# Saved: ./preprocessed_folder_final/B/val/55.jpg
# Saved: ./preprocessed_folder_final/B/val/54.jpg
# Saved: ./preprocessed_folder_final/B/val/51.jpg
# Saved: ./preprocessed_folder_final/B/val/53.jpg
# Saved: ./preprocessed_folder_final/B/val/52.jpg
#  All images processed, resized, and saved as .jpg.
